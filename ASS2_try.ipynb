# %%
import pandas as pd
import os

# %%
df = pd.read_excel(r"C:\Users\Niyas\Downloads\Table_10.1_Renewable_Energy_Production_and_Consumption_by_Source.xlsx",header=10)

# %%
rows_to_drop = list(range(9))
df_filtered = df.drop(rows_to_drop)
df_filtered
# Out:
#          Month Wood Energy Production Biofuels Production  \
# 9   1973-09-01                125.603       Not Available
# 10  1973-10-01                129.769       Not Available
# 11  1973-11-01                125.492       Not Available
# 12  1973-12-01                 129.69       Not Available
# 13  1974-01-01                130.655       Not Available
# ..         ...                    ...                 ...
# 605 2023-05-01                174.423             228.993
# 606 2023-06-01                167.973             230.103
# 607 2023-07-01                172.087             232.083
# 608 2023-08-01                176.694             230.241
# 609 2023-09-01                163.957              226.81
#
#     Total Biomass Energy Production Total Renewable Energy Production  \
# 9                           125.782                             185.3
# 10                           129.97                           193.514
# ...

# %%
df_filtered  = df.reset_index(drop=True)
df_filtered  = df.drop(0)

df_filtered
# Out:
#          Month Wood Energy Production Biofuels Production  \
# 1   1973-01-01                 129.63       Not Available
# 2   1973-02-01                117.194       Not Available
# 3   1973-03-01                129.763       Not Available
# 4   1973-04-01                125.462       Not Available
# 5   1973-05-01                129.624       Not Available
# ..         ...                    ...                 ...
# 605 2023-05-01                174.423             228.993
# 606 2023-06-01                167.973             230.103
# 607 2023-07-01                172.087             232.083
# 608 2023-08-01                176.694             230.241
# 609 2023-09-01                163.957              226.81
#
#     Total Biomass Energy Production Total Renewable Energy Production  \
# 1                           129.787                           219.839
# 2                           117.338                            197.33
# ...

# %%
# Selecting columns related to production
production_columns = ['Month', 'Wood Energy Production', 'Biofuels Production', 'Total Biomass Energy Production',
                       'Total Renewable Energy Production']
df_production = df[production_columns]
df_production = df_production.drop(0)

# Selecting columns related to consumption
consumption_columns = ['Month', 'Hydroelectric Power Consumption', 'Geothermal Energy Consumption',
                       'Solar Energy Consumption', 'Wind Energy Consumption', 'Wood Energy Consumption', 'Waste Energy Consumption',
                       'Biofuels Consumption', 'Total Biomass Energy Consumption', 'Total Renewable Energy Consumption']

df_consumption = df[consumption_columns]
df_consumption = df_consumption.drop(0)

# %%
df_production
# Out:
#          Month Wood Energy Production Biofuels Production  \
# 1   1973-01-01                 129.63       Not Available
# 2   1973-02-01                117.194       Not Available
# 3   1973-03-01                129.763       Not Available
# 4   1973-04-01                125.462       Not Available
# 5   1973-05-01                129.624       Not Available
# ..         ...                    ...                 ...
# 605 2023-05-01                174.423             228.993
# 606 2023-06-01                167.973             230.103
# 607 2023-07-01                172.087             232.083
# 608 2023-08-01                176.694             230.241
# 609 2023-09-01                163.957              226.81
#
#     Total Biomass Energy Production Total Renewable Energy Production
# 1                           129.787                           219.839
# 2                           117.338                            197.33
# ...

# %%
df_consumption
# Out:
#          Month Hydroelectric Power Consumption Geothermal Energy Consumption  \
# 1   1973-01-01                          89.562                          0.49
# 2   1973-02-01                          79.544                         0.448
# 3   1973-03-01                          88.284                         0.464
# 4   1973-04-01                          83.152                         0.542
# 5   1973-05-01                          85.643                         0.505
# ..         ...                             ...                           ...
# 605 2023-05-01                          93.759                         10.07
# 606 2023-06-01                          66.434                         9.562
# 607 2023-07-01                          72.463                          9.84
# 608 2023-08-01                           72.15                         9.967
# 609 2023-09-01                          56.284                         9.828
#
# ...

# %%
c= pd.read_csv(r"C:\Users\Niyas\Downloads\iou_zipcodes_2020.csv")

# %%
c
# Out:
#          zip  eiaid        utility_name state service_type       ownership  \
# 0      85321    176  Ajo Improvement Co    AZ      Bundled  Investor Owned
# 1      36560    195    Alabama Power Co    AL      Bundled  Investor Owned
# 2      36513    195    Alabama Power Co    AL      Bundled  Investor Owned
# 3      36280    195    Alabama Power Co    AL      Bundled  Investor Owned
# 4      35473    195    Alabama Power Co    AL      Bundled  Investor Owned
# ...      ...    ...                 ...   ...          ...             ...
# 52172  96146  57483   Liberty Utilities    CA      Bundled  Investor Owned
# 52173  96161  57483   Liberty Utilities    CA      Bundled  Investor Owned
# 52174  96133  57483   Liberty Utilities    CA      Bundled  Investor Owned
# 52175  96118  57483   Liberty Utilities    CA      Bundled  Investor Owned
# 52176  96107  57483   Liberty Utilities    CA      Bundled  Investor Owned
#
#        comm_rate  ind_rate  res_rate
# ...
